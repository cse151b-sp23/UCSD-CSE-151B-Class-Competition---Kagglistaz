# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from tqdm import tqdm


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /kaggle/input/ucsd-cse-151b-class-competition/feature_engineering.ipynb
# /kaggle/input/ucsd-cse-151b-class-competition/archive/test_public.csv
# /kaggle/input/ucsd-cse-151b-class-competition/archive/sampleSubmission.csv
# /kaggle/input/ucsd-cse-151b-class-competition/archive/train.csv
# /kaggle/input/ucsd-cse-151b-class-competition/archive/metaData_taxistandsID_name_GPSlocation.csv

# %%
# read the csv files
test = pd.read_csv('/kaggle/input/ucsd-cse-151b-class-competition/archive/test_public.csv')
train = pd.read_csv('/kaggle/input/ucsd-cse-151b-class-competition/archive/train.csv')
meta = pd.read_csv('/kaggle/input/ucsd-cse-151b-class-competition/archive/metaData_taxistandsID_name_GPSlocation.csv')

sampleSub = pd.read_csv('/kaggle/input/ucsd-cse-151b-class-competition/archive/sampleSubmission.csv')

# %%
train.head()
# Out:
#                TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 0  1372636858620000589         C          NaN           NaN  20000589
# 1  1372637303620000596         B          NaN           7.0  20000596
# 2  1372636951620000320         C          NaN           NaN  20000320
# 3  1372636854620000520         C          NaN           NaN  20000520
# 4  1372637091620000337         C          NaN           NaN  20000337
#
#     TIMESTAMP DAY_TYPE  MISSING_DATA  \
# 0  1372636858        A         False
# 1  1372637303        A         False
# 2  1372636951        A         False
# 3  1372636854        A         False
# 4  1372637091        A         False
#
#                                             POLYLINE
# 0  [[-8.618643,41.141412],[-8.618499,41.141376],[...
# 1  [[-8.639847,41.159826],[-8.640351,41.159871],[...
# 2  [[-8.612964,41.140359],[-8.613378,41.14035],[-...
# 3  [[-8.574678,41.151951],[-8.574705,41.151942],[...
# 4  [[-8.645994,41.18049],[-8.645949,41.180517],[-...

# %%
test.head()
# Out:
#   TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID   TIMESTAMP DAY_TYPE  \
# 0      T1         B          NaN          15.0  20000542  1408039037        A
# 1      T2         B          NaN          57.0  20000108  1408038611        A
# 2      T3         B          NaN          15.0  20000370  1408038568        A
# 3      T4         B          NaN          53.0  20000492  1408039090        A
# 4      T5         B          NaN          18.0  20000621  1408039177        A
#
#    MISSING_DATA
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
sampleSub.head()
# Out:
#   TRIP_ID  TRAVEL_TIME
# 0      T1          660
# 1      T2          660
# 2      T3          660
# 3      T4          660
# 4      T5          660

# %%
test.head()
# Out:
#   TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID   TIMESTAMP DAY_TYPE  \
# 0      T1         B          NaN          15.0  20000542  1408039037        A
# 1      T2         B          NaN          57.0  20000108  1408038611        A
# 2      T3         B          NaN          15.0  20000370  1408038568        A
# 3      T4         B          NaN          53.0  20000492  1408039090        A
# 4      T5         B          NaN          18.0  20000621  1408039177        A
#
#    MISSING_DATA
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
meta.head()
# Out:
#    ID  Descricao       Latitude  Longitude
# 0   1       Agra  41.1771457135  -8.609670
# 1   2    Alameda    41.15618964  -8.591064
# 2   3     Aldoar  41.1705249231  -8.665876
# 3   4  Alfândega  41.1437639911  -8.621803
# 4   5      Amial  41.1835097223  -8.612726

# %%
print(train.shape)
print(test.shape)
print(sampleSub.shape)
print(meta.shape)
# Out:
# (1710670, 9)
# (320, 8)
# (320, 2)
# (63, 4)

# %%
#observe what the polyline data looks like
train['POLYLINE'][0]
# Out:
# '[[-8.618643,41.141412],[-8.618499,41.141376],[-8.620326,41.14251],[-8.622153,41.143815],[-8.623953,41.144373],[-8.62668,41.144778],[-8.627373,41.144697],[-8.630226,41.14521],[-8.632746,41.14692],[-8.631738,41.148225],[-8.629938,41.150385],[-8.62911,41.151213],[-8.629128,41.15124],[-8.628786,41.152203],[-8.628687,41.152374],[-8.628759,41.152518],[-8.630838,41.15268],[-8.632323,41.153022],[-8.631144,41.154489],[-8.630829,41.154507],[-8.630829,41.154516],[-8.630829,41.154498],[-8.630838,41.154489]]'

# %%
#identify amount/proportion of "is missing" data
train['MISSING_DATA'].sum()
# Out:
# 10

# %%
#james's function to convert polyline to seconds quickly
def polyline_to_trip_duration(polyline):
  return max(polyline.count("[") - 2, 0) * 15

# %%
out = train["POLYLINE"].apply(polyline_to_trip_duration)
out.describe()
#sns.histplot(out)
# Out:
# count    1.710670e+06
# mean     7.164265e+02
# std      6.847512e+02
# min      0.000000e+00
# 25%      4.050000e+02
# 50%      6.000000e+02
# 75%      8.700000e+02
# max      5.820000e+04
# Name: POLYLINE, dtype: float64

# %%
arr = np.array(out)
arr.max()
# Out:
# 58200

# %%
from datetime import datetime
def parse_time(x):
  # We are using python's builtin datetime library
  # https://docs.python.org/3/library/datetime.html#datetime.date.fromtimestamp

  # Each x is essentially a 1 row, 1 column pandas Series
    dtStart = datetime.fromtimestamp(x["TIMESTAMP"])
    dtEnd = datetime.fromtimestamp(x["END_TIMESTAMP"])
    return dtStart.year, dtStart.month, dtStart.day, dtStart.hour, dtStart.minute, dtStart.weekday(), dtEnd.hour, dtEnd.minute

# %%
#too many entries with 0 second trip times, count them
frequency = np.count_nonzero(arr == 0)
frequency
# Out:
# 36510

# %%
#Get proportion of NaN values for ORIGIN_CALL
train['ORIGIN_CALL'].isna().sum() / train.shape[0]
# Out:
# 0.7867677576622025

# %%
#Get proportion of duplicate trips (sharing ids assumed to be duplicate)
trips = len(train['TRIP_ID'].unique())
print((train.shape[0] - trips) / train.shape[0])
# Out:
# 4.73498687648699e-05

# %%
#identify duplicate IDs
dup = train[train.duplicated(['TRIP_ID'])]
print(dup['TRIP_ID'].unique())
# Out:
# [1372702836620000080 1373025987620000601 1373210896620000598
#  1373551710620000014 1374014097620000337 1374151597620000080
#  1374157861620000328 1374262188620000554 1378607552620000403
#  1378830230620000435 1378866507620000648 1381308181620000352
#  1381645412620000328 1381765723620000392 1381859675620000465
#  1382450880620000432 1383341250620000588 1383557098620000562
#  1385631430620000080 1385772222620000263 1385928574620000080
#  1385928575620000080 1386167379620000080 1386942349620000080
#  1386947218620000080 1387206043620000080 1387839159620000080
#  1387937085620000080 1387909459620000429 1388279758620000080
#  1388526838620000080 1389002485620000685 1389561280620000080
#  1389782974620000562 1391186543620000513 1391416612620000196
#  1391586783620000484 1391717369620000663 1391729840620000663
#  1391931520620000286 1392271509620000286 1392317061620000066
#  1392499655620000663 1392640481620000663 1392816672620000663
#  1393315427620000513 1393462842620000620 1393472034620000620
#  1393686091620000161 1393869017620000066 1394034338620000328
#  1394118360620000066 1394207135620000588 1395055378620000315
#  1395682280620000089 1396333938620000397 1397121307620000196
#  1397172149620000454 1397199117620000513 1397742650620000393
#  1398185156620000066 1398185157620000066 1399224694620000548
#  1399908941620000099 1399918717620000571 1400060661620000080
#  1401307305620000129 1401346641620000319 1401469148620000104
#  1401826158620000196 1401840748620000196 1402085470620000527
#  1402132342620000571 1402586210620000400 1402716036620000243
#  1403115272620000066 1403323491620000600 1403407180620000242
#  1403716904620000337 1404093316620000307]

# %%
#Get the number of unique taxis across test and train datasets
print(train['TAXI_ID'].unique().shape)
print(len(set(test['TAXI_ID']).intersection(set(train['TAXI_ID']))))
print(len(set(test['TAXI_ID'])))
# Out:
# (448,)
# 244
# 244

# %%
#Get the number of unique taxis across test and train datasets
print(train['TAXI_ID'].unique().shape)
print(len(set(test['TAXI_ID']).intersection(set(train['TAXI_ID']))))
print(len(set(test['TAXI_ID'])))
# Out:
# (448,)
# 244
# 244

# %%
#track all latitiude and longitude points collected by the taxis
import plotly.express as px
trips = train['POLYLINE'][:]
allTripsLat = {}
allTripsLong = {}
tripsLat = []
tripsLong = []
xcoord = 0
xcoordx = 0
testcoords = 0
j = 0
i = 0
for x in tqdm(trips):
    #print(j)
    if x != '[]':
        testcoords = x[1:-1].replace('],[', ']/[').split('/')
        for xcoord in testcoords:
            #print(i)
            xcoordx = xcoord[1:-1].split(',')
            long = float(xcoordx[0])
            lat = float(xcoordx[1])
            allTripsLat[i] = lat
            allTripsLong[i] = long
            tripsLat.append(lat)
            tripsLong.append(long)
            
            i = i + 1
    j = j+1
#print(allTripsLat)
#print(allTripsLong)
# Out:
# 100%|██████████| 1710670/1710670 [01:45<00:00, 16243.92it/s]

# %%
#generate heatmap
x_min, x_max = np.min(tripsLat), np.max(tripsLat)
y_min, y_max = np.min(tripsLong), np.max(tripsLong)
heatmap, xedges, yedges = np.histogram2d(tripsLong, tripsLat, bins=300, range=[[-8.7, -8.55], [41.125, 41.250]]) #[[41.125, 41.250], [-8.7, -8.55]]
print(len(tripsLong))
# Create a meshgrid for the heatmap
x, y = np.meshgrid(xedges[:-1], yedges[:-1])
# Plot the heatmap
plt.figure(figsize=(10, 8))
plt.pcolormesh(x, y, heatmap.T, cmap='hot')
plt.colorbar(label='Frequency')
plt.title('Latitude-Longitude Heatmap')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# 83409386

# %% [markdown]
# TRAINING DATA PREPROCESSING

# %%
#reread original csv and sort by time
train.sort_values('TIMESTAMP',inplace = True)
train.head()
# Out:
#                  TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 577  1372636853620000380         C          NaN           NaN  20000380
# 3    1372636854620000520         C          NaN           NaN  20000520
# 0    1372636858620000589         C          NaN           NaN  20000589
# 10   1372636875620000233         C          NaN           NaN  20000233
# 64   1372636896620000360         C          NaN           NaN  20000360
#
#       TIMESTAMP DAY_TYPE  MISSING_DATA  \
# 577  1372636853        A         False
# 3    1372636854        A         False
# 0    1372636858        A         False
# 10   1372636875        A         False
# 64   1372636896        A         False
#
#                                               POLYLINE
# 577  [[-8.610291,41.140746],[-8.6103,41.140755],[-8...
# 3    [[-8.574678,41.151951],[-8.574705,41.151942],[...
# 0    [[-8.618643,41.141412],[-8.618499,41.141376],[...
# 10   [[-8.619894,41.148009],[-8.620164,41.14773],[-...
# 64   [[-8.617599,41.146137],[-8.617581,41.14593],[-...

# %%
train.describe()
# Out:
#             TRIP_ID    ORIGIN_CALL   ORIGIN_STAND       TAXI_ID     TIMESTAMP
# count  1.710670e+06  364770.000000  806579.000000  1.710670e+06  1.710670e+06
# mean   1.388622e+18   24490.363018      30.272381  2.000035e+07  1.388622e+09
# std    9.180944e+15   19624.290043      17.747840  2.112405e+02  9.180944e+06
# min    1.372637e+18    2001.000000       1.000000  2.000000e+07  1.372637e+09
# 25%    1.380731e+18    6593.000000      15.000000  2.000017e+07  1.380731e+09
# 50%    1.388493e+18   18755.000000      27.000000  2.000034e+07  1.388493e+09
# 75%    1.396750e+18   40808.000000      49.000000  2.000052e+07  1.396750e+09
# max    1.404173e+18   63884.000000      63.000000  2.000098e+07  1.404173e+09

# %%
#drop rows with MISSING_DATA 
train_reduced = train[train['MISSING_DATA'] == False]
train_reduced = train_reduced.drop('MISSING_DATA', axis=1)
print(train_reduced.shape)

train_reduced.head()
# Out:
# (1710660, 8)
#                  TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 577  1372636853620000380         C          NaN           NaN  20000380
# 3    1372636854620000520         C          NaN           NaN  20000520
# 0    1372636858620000589         C          NaN           NaN  20000589
# 10   1372636875620000233         C          NaN           NaN  20000233
# 64   1372636896620000360         C          NaN           NaN  20000360
#
#       TIMESTAMP DAY_TYPE                                           POLYLINE
# 577  1372636853        A  [[-8.610291,41.140746],[-8.6103,41.140755],[-8...
# 3    1372636854        A  [[-8.574678,41.151951],[-8.574705,41.151942],[...
# 0    1372636858        A  [[-8.618643,41.141412],[-8.618499,41.141376],[...
# 10   1372636875        A  [[-8.619894,41.148009],[-8.620164,41.14773],[-...
# 64   1372636896        A  [[-8.617599,41.146137],[-8.617581,41.14593],[-...

# %%
#drop rows with empty polyline
print(train_reduced[train_reduced['POLYLINE'] =='[]'].shape)
train_reduced = train_reduced.drop(train_reduced[train_reduced['POLYLINE'] =='[]']['POLYLINE'].index)
#train = train.drop(train[train['POLYLINE'] == '[]']['POLYLINE'].index, inplace = True)
print(train_reduced.shape)
# Out:
# (5901, 8)
# (1704759, 8)

# %%
#use james zhao's function to convert polyline into trip time in secs
train_reduced["tripTimeSec"] = train_reduced["POLYLINE"].apply(polyline_to_trip_duration)
print(train_reduced.shape)
# Out:
# (1704759, 9)

# %%
train_reduced['END_TIMESTAMP'] = train_reduced['TIMESTAMP'] + train_reduced['tripTimeSec']
train_reduced.head()
# Out:
#                  TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 577  1372636853620000380         C          NaN           NaN  20000380
# 3    1372636854620000520         C          NaN           NaN  20000520
# 0    1372636858620000589         C          NaN           NaN  20000589
# 10   1372636875620000233         C          NaN           NaN  20000233
# 64   1372636896620000360         C          NaN           NaN  20000360
#
#       TIMESTAMP DAY_TYPE                                           POLYLINE  \
# 577  1372636853        A  [[-8.610291,41.140746],[-8.6103,41.140755],[-8...
# 3    1372636854        A  [[-8.574678,41.151951],[-8.574705,41.151942],[...
# 0    1372636858        A  [[-8.618643,41.141412],[-8.618499,41.141376],[...
# 10   1372636875        A  [[-8.619894,41.148009],[-8.620164,41.14773],[-...
# 64   1372636896        A  [[-8.617599,41.146137],[-8.617581,41.14593],[-...
#
#      tripTimeSec  END_TIMESTAMP
# 577          360     1372637213
# 3            630     1372637484
# 0            330     1372637188
# 10           315     1372637190
# 64           630     1372637526

# %%
#drop entries with 0 length trip time - may be somethig to address later
train_reduced = train_reduced.drop(train_reduced[train_reduced['tripTimeSec'] ==0]['tripTimeSec'].index)
print(train_reduced.shape)
# Out:
# (1674152, 10)

# %%
#tconvert the timestamp into proper data/time
train_reduced[["YR", "MON", "DAY", "START_HR", "START_MIN", "WK_DAY", "END_HR", "END_MIN"]] = train_reduced[['TIMESTAMP', 'END_TIMESTAMP']].apply(parse_time, axis=1, result_type="expand")

print(train_reduced.shape)

train_reduced.head()
# Out:
# (1674152, 18)
#                  TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 577  1372636853620000380         C          NaN           NaN  20000380
# 3    1372636854620000520         C          NaN           NaN  20000520
# 0    1372636858620000589         C          NaN           NaN  20000589
# 10   1372636875620000233         C          NaN           NaN  20000233
# 64   1372636896620000360         C          NaN           NaN  20000360
#
#       TIMESTAMP DAY_TYPE                                           POLYLINE  \
# 577  1372636853        A  [[-8.610291,41.140746],[-8.6103,41.140755],[-8...
# 3    1372636854        A  [[-8.574678,41.151951],[-8.574705,41.151942],[...
# 0    1372636858        A  [[-8.618643,41.141412],[-8.618499,41.141376],[...
# 10   1372636875        A  [[-8.619894,41.148009],[-8.620164,41.14773],[-...
# 64   1372636896        A  [[-8.617599,41.146137],[-8.617581,41.14593],[-...
#
#      tripTimeSec  END_TIMESTAMP    YR  MON  DAY  START_HR  START_MIN  WK_DAY  \
# 577          360     1372637213  2013    7    1         0          0       0
# 3            630     1372637484  2013    7    1         0          0       0
# 0            330     1372637188  2013    7    1         0          0       0
# 10           315     1372637190  2013    7    1         0          1       0
# 64           630     1372637526  2013    7    1         0          1       0
#
#      END_HR  END_MIN
# 577       0        6
# 3         0       11
# 0         0        6
# 10        0        6
# 64        0       12

# %%
#Drop day_type col
train_reduced = train_reduced.drop('DAY_TYPE', axis=1)
print(train_reduced.shape)
# Out:
# (1674152, 17)

# %%
#drop duplicated trip id
train_reduced = train_reduced.drop_duplicates(subset=['TRIP_ID'])
print(train_reduced.shape)
# Out:
# (1674141, 17)

# %%
#drop trips with lengths longer than three standard deviations
mean = train_reduced['tripTimeSec'].mean()
std = train_reduced['tripTimeSec'].std()
outlier_threshold = 3
print(mean)
print(std)
threshold = mean + outlier_threshold * std
train_reduced = train_reduced[train_reduced['tripTimeSec'] < threshold]
print(train_reduced.shape)
# Out:
# 732.0483400143715
# 683.842580336944
# (1656475, 17)

# %%
mean = train_reduced['tripTimeSec'].mean()
std = train_reduced['tripTimeSec'].std()
print('mean: ' + str(mean))
print('std: ' + str(std))
print(train_reduced.shape)
sns.histplot(train_reduced['tripTimeSec'])
plt.axvline(x=mean, color='red')
plt.axvline(x=np.median(train_reduced['tripTimeSec']), color='yellow')
plt.title('histogram of trip length in seconds : prefiltering')
plt.xlabel("Trip Time (s)")
# Out:
# mean: 687.1165698244766
# std: 397.7629894750145
# (1656475, 17)
# Text(0.5, 0, 'Trip Time (s)')

# %%
#convert NaNs in origincall/origin stand to zeros
train_reduced[["ORIGIN_CALL", "ORIGIN_STAND"]] = train_reduced[["ORIGIN_CALL", "ORIGIN_STAND"]].fillna(0)
train_reduced.head()
# Out:
#                  TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 577  1372636853620000380         C          0.0           0.0  20000380
# 3    1372636854620000520         C          0.0           0.0  20000520
# 0    1372636858620000589         C          0.0           0.0  20000589
# 10   1372636875620000233         C          0.0           0.0  20000233
# 64   1372636896620000360         C          0.0           0.0  20000360
#
#       TIMESTAMP                                           POLYLINE  \
# 577  1372636853  [[-8.610291,41.140746],[-8.6103,41.140755],[-8...
# 3    1372636854  [[-8.574678,41.151951],[-8.574705,41.151942],[...
# 0    1372636858  [[-8.618643,41.141412],[-8.618499,41.141376],[...
# 10   1372636875  [[-8.619894,41.148009],[-8.620164,41.14773],[-...
# 64   1372636896  [[-8.617599,41.146137],[-8.617581,41.14593],[-...
#
#      tripTimeSec  END_TIMESTAMP    YR  MON  DAY  START_HR  START_MIN  WK_DAY  \
# 577          360     1372637213  2013    7    1         0          0       0
# 3            630     1372637484  2013    7    1         0          0       0
# 0            330     1372637188  2013    7    1         0          0       0
# 10           315     1372637190  2013    7    1         0          1       0
# 64           630     1372637526  2013    7    1         0          1       0
#
#      END_HR  END_MIN
# 577       0        6
# 3         0       11
# 0         0        6
# 10        0        6
# 64        0       12

# %%
#add columns with the starting latitude, longitude , and stand name for each trip. if nan then we will use 0.0
def create_dictionary(df):
    dictionary = {}
    for index, row in df.iterrows():
        id = row['ID']
        loc = row['Descricao']
        latitude = row['Latitude']
        longitude = row['Longitude']
        latitude, longitude = split_string(latitude, longitude)
        dictionary[id] = (loc, latitude, longitude)
    dictionary[0] = ('None', 0.0, 0.0)
    return dictionary

def split_string(lat, lng):
    if '-' in lat and lat.index('-') != 0:
        index = lat.find('-')
        left = lat[0:index]
        right = lat[index:]
        return float(left), float(right)
    else:
        return float(lat), float(lng)

standDict = create_dictionary(meta)
standDict
# Out:
# {1: ('Agra', 41.1771457135, -8.6096702714),
#  2: ('Alameda', 41.15618964, -8.59106440506),
#  3: ('Aldoar', 41.1705249231, -8.66587593213),
#  4: ('Alfândega', 41.1437639911, -8.62180322015),
#  5: ('Amial', 41.1835097223, -8.61272586967),
#  6: ('Areosa', 41.1808043369, -8.58278289063),
#  7: ('Av. Boavista', 41.1599801853, -8.64198392478),
#  8: ('Azevedo', 41.1515920975, -8.56819539682),
#  9: ('Batalha', 41.1442525263, -8.60571961615),
#  10: ('Bolhão', 41.1507106526, -8.60690977259),
#  11: ('Bom Pastor', 41.1670339026, -8.61326686188),
#  12: ('Bom Sucesso', 41.1551197292, -8.63046626628),
#  13: ('Brasília', 41.1570891314, -8.6284679801),
#  14: ('Câmara', 41.1497021913, -8.6110708703),
#  15: ('Campanhã', 41.1486275073, -8.58587660305),
#  16: ('Campismo', 41.1754722349, -8.62779145139),
#  17: ('Carcereira', 41.1644515812, -8.63228595529),
#  18: ('Carregal', 41.1483209068, -8.61960347647),
#  19: ('Carvalheiras', 41.1535929278, -8.60542646661),
#  20: ('Carvalhido', 41.1669278236, -8.62677872999),
#  21: ('Casa da Musica', 41.160886353, -8.62956506919),
#  22: ('Castelo do Queijo', 41.168317889, -8.68917996027),
#  23: ('Clérigos', 41.1460158298, -8.61257471887),
#  24: ('Conde Ferreira', 41.1695302186, -8.58934789723),
#  25: ('Cordoaria', 41.146299872, -8.61763808774),
#  26: ('Corujeira', 41.1595606398, -8.57977594756),
#  27: ('D. João I', 41.1480321319, -8.60924112742),
#  28: ('Dragão', 41.1632224305, -8.58404677278),
#  29: ('Francos', 41.1710190954, -8.63866558117),
#  30: ('Galiza', 41.1517836424, -8.62775942991),
#  31: ('H. Magalhães Lemos', 41.1769535175, -8.66396032334),
#  32: ('H. Militar', 41.1576623087, -8.62704415185),
#  33: ('H. São João', 41.1827872098, -8.60012244419),
#  34: ('Infante', 41.1405168841, -8.6159521911),
#  35: ('Lago', 41.167431809, -8.64952681771),
#  36: ('Lordelo', 41.1546571224, -8.64907357792),
#  37: ('Marechal', 41.1610810603, -8.6575467588),
#  38: ('Marquês', 41.1607148883, -8.60424608207),
#  39: ('Maternidade', 41.1508914639, -8.62279999766),
#  40: ('Mercado da Foz', 41.1542337417, -8.6740067792),
#  41: ('Nevogilde', 41.163066654, -8.67598304213),
#  42: ('Nove de Abril', 41.1727485684, -8.61178358386),
#  43: ('Ouro', 41.1486110328, -8.64888643487),
#  44: ('Palácio', 41.149617396, -8.62578443669),
#  45: ('Passeio Alegre', 41.1486486007, -8.67279532851),
#  46: ('Pereira de Melo', 41.1786451618, -8.64853556975),
#  47: ('Pereiró', 41.1738135714, -8.65449600832),
#  48: ('Pinto de Azevedo', 41.171262373, -8.64505015387),
#  49: ('Pólo Universitário', 41.1795510913, -8.60253898017),
#  50: ('Prelada', 41.169838306, -8.62890245375),
#  51: ('Ramada Alta', 41.1614038495, -8.62112197229),
#  52: ('Républica', 41.1549650972, -8.61321698848),
#  53: ('Ribeira', 41.1412081961, -8.61401226127),
#  54: ('Rotunda', 41.1580038805, -8.63037495014),
#  55: ('São Roque', 41.166000771, -8.57035176235),
#  56: ('Sá Carneiro', 41.1628786974, -8.59164528176),
#  57: ('São Bento', 41.1457188058, -8.61070701502),
#  58: ('Terço', 41.1615915925, -8.60452832992),
#  59: ('Tenente Valadim', 41.1607030178, -8.64120474891),
#  60: ('Trindade', 41.1511237005, -8.60984340203),
#  61: ('Vinte e Quatro de Agosto', 41.1493101131, -8.60030852546),
#  62: ('Viso', 41.1778737602, -8.64655750451),
#  63: ('Santa Maria', 41.1603753216, -8.60936972153),
#  0: ('None', 0.0, 0.0)}

# %%
train_reduced.head()
augustorlater = train_reduced[train_reduced['MON'] > 7]
print(augustorlater.shape)
augustorlater.head()
# Out:
# (691501, 17)
#                     TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 145232  1375315249620000269         C          0.0           0.0  20000269
# 145267  1375315259620000570         C          0.0           0.0  20000570
# 145314  1375315271620000309         C          0.0           0.0  20000309
# 145303  1375315280620000367         B          0.0          15.0  20000367
# 145477  1375315372620000003         B          0.0           9.0  20000003
#
#          TIMESTAMP                                           POLYLINE  \
# 145232  1375315249  [[-8.610813,41.167404],[-8.611137,41.167467],[...
# 145267  1375315259  [[-8.612937,41.141511],[-8.608761,41.140971],[...
# 145314  1375315271  [[-8.609679,41.151285],[-8.609625,41.151294],[...
# 145303  1375315280  [[-8.585658,41.148513],[-8.585694,41.148927],[...
# 145477  1375315372  [[-8.606475,41.144544],[-8.607087,41.144697],[...
#
#         tripTimeSec  END_TIMESTAMP    YR  MON  DAY  START_HR  START_MIN  \
# 145232          315     1375315564  2013    8    1         0          0
# 145267         1170     1375316429  2013    8    1         0          0
# 145314          300     1375315571  2013    8    1         0          1
# 145303          210     1375315490  2013    8    1         0          1
# 145477          780     1375316152  2013    8    1         0          2
#
#         WK_DAY  END_HR  END_MIN
# 145232       3       0        6
# 145267       3       0       20
# 145314       3       0        6
# 145303       3       0        4
# 145477       3       0       15

# %%
two30 = train_reduced.loc[((train_reduced['START_HR'] == 14) & (train_reduced['START_MIN'] >= 0) & (train_reduced['START_MIN'] <= 30)) | ((train_reduced['END_HR'] == 14) & (train_reduced['END_MIN'] >= 15) & (train_reduced['END_MIN'] <= 45))]
print(two30.shape)
two30.head()
# Out:
# (54379, 17)
#                   TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 2601  1372686333620000247         B          0.0          56.0  20000247
# 3005  1372686607620000502         A       8402.0           0.0  20000502
# 3831  1372686755620000571         A      63882.0           0.0  20000571
# 2483  1372686816620000076         C          0.0           0.0  20000076
# 2702  1372686874620000258         B          0.0           7.0  20000258
#
#        TIMESTAMP                                           POLYLINE  \
# 2601  1372686333  [[-8.591364,41.162751],[-8.590995,41.162499],[...
# 3005  1372686607  [[-8.641629,41.161446],[-8.641629,41.161419],[...
# 3831  1372686755  [[-8.593542,41.164407],[-8.593416,41.164641],[...
# 2483  1372686816  [[-8.608005,41.148279],[-8.608023,41.14863],[-...
# 2702  1372686874  [[-8.639784,41.159736],[-8.64045,41.15979],[-8...
#
#       tripTimeSec  END_TIMESTAMP    YR  MON  DAY  START_HR  START_MIN  WK_DAY  \
# 2601         2160     1372688493  2013    7    1        13         45       0
# 3005         2550     1372689157  2013    7    1        13         50       0
# 3831         1410     1372688165  2013    7    1        13         52       0
# 2483         1425     1372688241  2013    7    1        13         53       0
# 2702         2010     1372688884  2013    7    1        13         54       0
#
#       END_HR  END_MIN
# 2601      14       21
# 3005      14       32
# 3831      14       16
# 2483      14       17
# 2702      14       28

# %%
five45 = train_reduced.loc[((train_reduced['START_HR'] == 17) & (train_reduced['START_MIN'] >= 15) & (train_reduced['START_MIN'] <= 45)) | (((train_reduced['END_HR'] == 17) & (train_reduced['END_MIN'] >= 30)) | ((train_reduced['END_HR'] == 18) & (train_reduced['END_MIN'] == 0)))]
print(five45.shape)
five45.head()
# Out:
# (49581, 17)
#                   TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 5032  1372698111620000229         B          0.0          54.0  20000229
# 3868  1372698208620000455         C          0.0           0.0  20000455
# 5916  1372698357620000419         C          0.0           0.0  20000419
# 3687  1372698399620000326         B          0.0          62.0  20000326
# 3371  1372698496620000454         B          0.0           0.0  20000454
#
#        TIMESTAMP                                           POLYLINE  \
# 5032  1372698111  [[-8.630109,41.157369],[-8.630082,41.157351],[...
# 3868  1372698208  [[-8.683515,41.163282],[-8.684082,41.163363],[...
# 5916  1372698357  [[-8.627751,41.157603],[-8.627796,41.157666],[...
# 3687  1372698399  [[-8.646516,41.177745],[-8.646192,41.177133],[...
# 3371  1372698496  [[-8.612604,41.145921],[-8.612658,41.145939],[...
#
#       tripTimeSec  END_TIMESTAMP    YR  MON  DAY  START_HR  START_MIN  WK_DAY  \
# 5032         1860     1372699971  2013    7    1        17          1       0
# 3868         2700     1372700908  2013    7    1        17          3       0
# 5916         1500     1372699857  2013    7    1        17          5       0
# 3687         2190     1372700589  2013    7    1        17          6       0
# 3371         1335     1372699831  2013    7    1        17          8       0
#
#       END_HR  END_MIN
# 5032      17       32
# 3868      17       48
# 5916      17       30
# 3687      17       43
# 3371      17       30

# %%
six0 = train_reduced.loc[(((train_reduced['START_HR'] == 17) & (train_reduced['START_MIN'] >= 30)) | ((train_reduced['START_HR'] == 18) & (train_reduced['START_MIN'] == 0))) | (((train_reduced['END_HR'] == 17) & (train_reduced['END_MIN'] >= 45)) | ((train_reduced['END_HR'] == 18) & ((train_reduced['END_MIN'] <= 15))))]
print(six0.shape)
six0.head()
# Out:
# (49890, 17)
#                   TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 3868  1372698208620000455         C          0.0           0.0  20000455
# 5449  1372698680620000464         C          0.0           0.0  20000464
# 3667  1372699159620000598         A      22362.0           0.0  20000598
# 3602  1372699297620000387         B          0.0          36.0  20000387
# 3594  1372699494620000118         A      40721.0           0.0  20000118
#
#        TIMESTAMP                                           POLYLINE  \
# 3868  1372698208  [[-8.683515,41.163282],[-8.684082,41.163363],[...
# 5449  1372698680  [[-8.69004,41.174928],[-8.689491,41.174217],[-...
# 3667  1372699159  [[-8.656227,41.153292],[-8.656146,41.153301],[...
# 3602  1372699297  [[-8.649459,41.154264],[-8.650188,41.154129],[...
# 3594  1372699494  [[-8.576766,41.143437],[-8.57682,41.143482],[-...
#
#       tripTimeSec  END_TIMESTAMP    YR  MON  DAY  START_HR  START_MIN  WK_DAY  \
# 3868         2700     1372700908  2013    7    1        17          3       0
# 5449         2595     1372701275  2013    7    1        17         11       0
# 3667         1980     1372701139  2013    7    1        17         19       0
# 3602         1980     1372701277  2013    7    1        17         21       0
# 3594         1305     1372700799  2013    7    1        17         24       0
#
#       END_HR  END_MIN
# 3868      17       48
# 5449      17       54
# 3667      17       52
# 3602      17       54
# 3594      17       46

# %%
four0 = train_reduced.loc[(((train_reduced['START_HR'] == 3) & (train_reduced['START_MIN'] >= 30)) | ((train_reduced['START_HR'] == 4) & (train_reduced['START_MIN'] == 0))) | (((train_reduced['END_HR'] == 3) & (train_reduced['END_MIN'] >= 45)) | ((train_reduced['END_HR'] == 4) & ((train_reduced['END_MIN'] <= 15))))]
print(four0.shape)
four0.head()
# Out:
# (33321, 17)
#                  TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 201  1372649085620000569         C          0.0           0.0  20000569
# 525  1372649132620000574         C          0.0           0.0  20000574
# 206  1372649178620000153         C          0.0           0.0  20000153
# 212  1372649323620000496         C          0.0           0.0  20000496
# 202  1372649452620000436         C          0.0           0.0  20000436
#
#       TIMESTAMP                                           POLYLINE  \
# 201  1372649085  [[-8.660745,41.182335],[-8.664291,41.185206],[...
# 525  1372649132  [[-8.639514,41.164209],[-8.639568,41.163912],[...
# 206  1372649178  [[-8.668629,41.152014],[-8.666199,41.151033],[...
# 212  1372649323  [[-8.598105,41.197851],[-8.598132,41.197851],[...
# 202  1372649452  [[-8.63856,41.158953],[-8.638578,41.159097],[-...
#
#      tripTimeSec  END_TIMESTAMP    YR  MON  DAY  START_HR  START_MIN  WK_DAY  \
# 201         1455     1372650540  2013    7    1         3         24       0
# 525         2280     1372651412  2013    7    1         3         25       0
# 206         1860     1372651038  2013    7    1         3         26       0
# 212         1665     1372650988  2013    7    1         3         28       0
# 202          735     1372650187  2013    7    1         3         30       0
#
#      END_HR  END_MIN
# 201       3       49
# 525       4        3
# 206       3       57
# 212       3       56
# 202       3       43

# %%
eight30 = train_reduced.loc[((train_reduced['START_HR'] == 8) & (train_reduced['START_MIN'] >= 0) & (train_reduced['START_MIN'] <= 30)) | ((train_reduced['END_HR'] == 8) & (train_reduced['END_MIN'] >= 15) & (train_reduced['END_MIN'] <= 45))]
print(eight30.shape)
eight30.head()
# Out:
# (50955, 17)
#                    TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 710    1372664787620000397         A       5994.0           0.0  20000397
# 906    1372664866620000901         C          0.0           0.0  20000901
# 12027  1372665027620000574         C          0.0           0.0  20000574
# 913    1372665032620000541         B          0.0          15.0  20000541
# 941    1372665088620000186         C          0.0           0.0  20000186
#
#         TIMESTAMP                                           POLYLINE  \
# 710    1372664787  [[-8.620074,41.150979],[-8.620065,41.150952],[...
# 906    1372664866  [[-8.591166,41.175189],[-8.59158,41.176404],[-...
# 12027  1372665027  [[-8.671905,41.149638],[-8.67186,41.149242],[-...
# 913    1372665032  [[-8.585631,41.148522],[-8.585712,41.148666],[...
# 941    1372665088  [[-8.615529,41.162382],[-8.615511,41.162382],[...
#
#        tripTimeSec  END_TIMESTAMP    YR  MON  DAY  START_HR  START_MIN  \
# 710           1800     1372666587  2013    7    1         7         46
# 906           1875     1372666741  2013    7    1         7         47
# 12027         2445     1372667472  2013    7    1         7         50
# 913           1560     1372666592  2013    7    1         7         50
# 941           1770     1372666858  2013    7    1         7         51
#
#        WK_DAY  END_HR  END_MIN
# 710         0       8       16
# 906         0       8       19
# 12027       0       8       31
# 913         0       8       16
# 941         0       8       20

# %%
frames = [two30, five45, six0, four0, eight30]
train_reduced = pd.concat(frames)
train_reduced.shape
# Out:
# (238126, 17)

# %%
#hourVector = [11, 12, 13, 14, 15, 16, 17, 2, 3, 6, 7, 8]
#train_reduced = train_reduced[~train_reduced['START_HR'].isin(hourVector)]

# %%
train_reduced = train_reduced.drop_duplicates(subset=['TRIP_ID'])
train_reduced.shape
# Out:
# (208632, 17)

# %%
print(len(train_reduced['TAXI_ID'].unique()))
print(len(test['TAXI_ID'].unique()))
test_taxis = test['TAXI_ID'].unique()
train_reduced = train_reduced [train_reduced ['TAXI_ID'].isin(test_taxis)]
print(train_reduced.shape)
# Out:
# 440
# 244
# (122756, 17)

# %%
#continuation of previous code block
train_reduced['ORIGIN'] = train_reduced['ORIGIN_STAND'].map(lambda x: (standDict.get(x)[0]))
train_reduced['STAND_LAT'] = train_reduced['ORIGIN_STAND'].map(lambda x: (standDict.get(x)[1]))
train_reduced['STAND_LONG'] = train_reduced['ORIGIN_STAND'].map(lambda x: (standDict.get(x)[2]))

# %%
train_reduced.head()
# Out:
#                   TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 2601  1372686333620000247         B          0.0          56.0  20000247
# 3005  1372686607620000502         A       8402.0           0.0  20000502
# 2699  1372687013620000473         C          0.0           0.0  20000473
# 3087  1372687204620000406         B          0.0           6.0  20000406
# 2689  1372687220620000617         C          0.0           0.0  20000617
#
#        TIMESTAMP                                           POLYLINE  \
# 2601  1372686333  [[-8.591364,41.162751],[-8.590995,41.162499],[...
# 3005  1372686607  [[-8.641629,41.161446],[-8.641629,41.161419],[...
# 2699  1372687013  [[-8.570835,41.159979],[-8.569476,41.161176],[...
# 3087  1372687204  [[-8.582616,41.180229],[-8.582355,41.180247],[...
# 2689  1372687220  [[-8.689356,41.168088],[-8.688672,41.167359],[...
#
#       tripTimeSec  END_TIMESTAMP    YR  MON  DAY  START_HR  START_MIN  WK_DAY  \
# 2601         2160     1372688493  2013    7    1        13         45       0
# 3005         2550     1372689157  2013    7    1        13         50       0
# 2699         1170     1372688183  2013    7    1        13         56       0
# 3087         2280     1372689484  2013    7    1        14          0       0
# 2689          660     1372687880  2013    7    1        14          0       0
#
#       END_HR  END_MIN       ORIGIN  STAND_LAT  STAND_LONG
# 2601      14       21  Sá Carneiro  41.162879   -8.591645
# 3005      14       32         None   0.000000    0.000000
# 2699      14       16         None   0.000000    0.000000
# 3087      14       38       Areosa  41.180804   -8.582783
# 2689      14       11         None   0.000000    0.000000

# %%
train_reduced.head()
for index, value in train_reduced['ORIGIN_STAND'].iteritems():
    if float(value) == 33.0 or float(value) == 39.0:
        train_reduced.loc[index, 'IS_HOSPITAL'] = 1
    else:
        train_reduced.loc[index, 'IS_HOSPITAL'] = 0
    indexes = [2.0, 3.0, 26.0, 28.0, 44.0]
    if float(value) in indexes:
        train_reduced.loc[index, 'IS_STADIUM'] = 1
    else:
        train_reduced.loc[index, 'IS_STADIUM'] = 0
    indexes = [1.0, 25.0, 33.0, 42.0, 49.0]
    if float(value) in indexes:
        train_reduced.loc[index, 'IS_UNIV'] = 1
    else:
        train_reduced.loc[index, 'IS_UNIV'] = 0
    # Check if the value is within the range
    #if lower_bound <= value <= upper_bound:
    #    df.loc[index, 'NewColumn'] = 1
# Out:
# /tmp/ipykernel_34/2822383500.py:2: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for index, value in train_reduced['ORIGIN_STAND'].iteritems():

# %%
print(train_reduced[train_reduced['IS_STADIUM'] != 0].shape)
print(train_reduced[train_reduced['IS_UNIV'] != 0].shape)
print(train_reduced[train_reduced['IS_HOSPITAL'] != 0].shape)
# Out:
# (2316, 23)
# (5404, 23)
# (2330, 23)

# %%
def minute_to_quarter(x):
    if(x >= 0 and x < 15):
        return 1
    elif(x >= 15 and x < 30):
        return 2
    elif(x >= 30 and x < 45):
        return 3
    else:
        return 4
train_reduced["START_QTR"] = train_reduced["START_MIN"].apply(minute_to_quarter)
train_reduced["END_QTR"] = train_reduced["END_MIN"].apply(minute_to_quarter)

# %%
train_reduced.head()
# Out:
#                   TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 2601  1372686333620000247         B          0.0          56.0  20000247
# 3005  1372686607620000502         A       8402.0           0.0  20000502
# 2699  1372687013620000473         C          0.0           0.0  20000473
# 3087  1372687204620000406         B          0.0           6.0  20000406
# 2689  1372687220620000617         C          0.0           0.0  20000617
#
#        TIMESTAMP                                           POLYLINE  \
# 2601  1372686333  [[-8.591364,41.162751],[-8.590995,41.162499],[...
# 3005  1372686607  [[-8.641629,41.161446],[-8.641629,41.161419],[...
# 2699  1372687013  [[-8.570835,41.159979],[-8.569476,41.161176],[...
# 3087  1372687204  [[-8.582616,41.180229],[-8.582355,41.180247],[...
# 2689  1372687220  [[-8.689356,41.168088],[-8.688672,41.167359],[...
#
#       tripTimeSec  END_TIMESTAMP    YR  ...  END_HR  END_MIN       ORIGIN  \
# 2601         2160     1372688493  2013  ...      14       21  Sá Carneiro
# 3005         2550     1372689157  2013  ...      14       32         None
# 2699         1170     1372688183  2013  ...      14       16         None
# 3087         2280     1372689484  2013  ...      14       38       Areosa
# 2689          660     1372687880  2013  ...      14       11         None
#
#       STAND_LAT  STAND_LONG  IS_HOSPITAL  IS_STADIUM IS_UNIV  START_QTR  \
# 2601  41.162879   -8.591645          0.0         0.0     0.0          4
# 3005   0.000000    0.000000          0.0         0.0     0.0          4
# 2699   0.000000    0.000000          0.0         0.0     0.0          4
# 3087  41.180804   -8.582783          0.0         0.0     0.0          1
# 2689   0.000000    0.000000          0.0         0.0     0.0          1
#
#       END_QTR
# 2601        2
# 3005        3
# 2699        2
# 3087        3
# 2689        1
#
# [5 rows x 25 columns]

# %%
#create histograms of trip times for the following fields: ORIGIN_CALL", "ORIGIN_STAND", "TAXI_ID", "YR", "MON", "DAY", "HR", "WK", "STAND_LAT", "STAND_LONG
#tentative: origin_stand, taxi_id, hr, week, calltype, origin (red one only), and stand-long contain learnable information
end = -1
mean = train_reduced['tripTimeSec'].mean()
std = train_reduced['tripTimeSec'].std()
threshold = 3  # Set your threshold here

buckets = int((mean + threshold * std // 15))
print(buckets)

threshold = 10
buckets = (int(threshold) // 1) + 1  # Adjust the number of bins based on the threshold
print(buckets)

fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(18,14))

for idx, v in enumerate(["ORIGIN_CALL", "ORIGIN_STAND", "TAXI_ID", "YR", "MON", "DAY", "START_HR", "WK_DAY", "STAND_LAT", "STAND_LONG"]):
    ax = axs[idx // 4, idx % 4]
    df_subset = train_reduced.dropna(subset=[v])
    ax.hist2d(df_subset[v][:end], df_subset["tripTimeSec"][:end], cmap="CMRmap", bins=(120, buckets))
    ax.set_xlim(ax.get_xlim()[0] - 1, ax.get_xlim()[1] + 1)
    ax.set_facecolor("black")
    ax.set_ylabel("seconds", fontsize=18)
    ax.set_title(f"Feature: {v}", fontsize=20)
# Out:
# 836
# 11

# %%
# # Group the data by Year
# grouped_data = train.groupby('YR')['tripTimeSec'].agg(['mean', 'std'])

# # Plotting the bar chart
# x = grouped_data.index
# y = grouped_data['mean']
# error = grouped_data['std']

# plt.bar(x, y, yerr=error, capsize=4)
# plt.xlabel('Year')
# plt.ylabel('Average Travel Time (seconds)')
# plt.title('Distribution Year vs Travel Time')
# plt.show()

# %%
# Group the data by Month
grouped_data = train_reduced.groupby('MON')['tripTimeSec'].agg(['mean', 'std'])

# Plotting the bar chart
x = grouped_data.index
y = grouped_data['mean']
error = grouped_data['std']

plt.bar(x, y, yerr=error, capsize=4)
plt.xlabel('Month')
plt.ylabel('Average Travel Time (seconds)')
plt.title('Distribution Year vs Travel Time')
plt.show()

# %%
# Group the data by Day
grouped_data = train_reduced.groupby('DAY')['tripTimeSec'].agg(['mean', 'std'])

# Plotting the bar chart
x = grouped_data.index
y = grouped_data['mean']
error = grouped_data['std']

plt.bar(x, y, yerr=error, capsize=4)
plt.xlabel('Day')
plt.ylabel('Average Travel Time (seconds)')
plt.title('Distribution Day of Month vs Travel Time')
plt.show()

# %%
#chart out frequencies for different call types
plt.figure(figsize=(10,10))
for v in train_reduced['CALL_TYPE'].unique():
  # Filter data where the HR matches v
  myData = train_reduced[train_reduced["CALL_TYPE"] == v]["tripTimeSec"]
  histogram, bin_boundary = np.histogram(myData, bins=50)
  histogram = histogram / len(myData)
  # The center is the left_bound and right_bound of a bucket
    #bin_centers = [(bin_boundary[i] + bin_boundary[i + 1]) / 2 for i in range(buckets)]
  plt.plot(histogram, label=f"CallType={v}")
plt.legend();

# %%
#chart out frequencies for different taxi stops
plt.figure(figsize=(10,10))
for v in train_reduced['ORIGIN'].unique():
  # Filter data where the HR matches v
  myData = train_reduced[train_reduced["ORIGIN"] == v]["tripTimeSec"]
  histogram, bin_boundary = np.histogram(myData, bins=50)
  histogram = histogram / len(myData)
  # The center is the left_bound and right_bound of a bucket
    #bin_centers = [(bin_boundary[i] + bin_boundary[i + 1]) / 2 for i in range(buckets)]
  plt.plot(histogram, label=f"={v}")
plt.legend();

# %%
#save all fields into csv (except trip id, timestamp, polyline)
print(train_reduced.columns)
train_cleaned = train_reduced[['TRIP_ID', 'CALL_TYPE', 'ORIGIN_CALL', 'TAXI_ID', 'TIMESTAMP', 'END_TIMESTAMP', 'tripTimeSec', 'MON', 'DAY', 'WK_DAY', 'START_HR', 'START_MIN', 'START_QTR', 'END_HR', 'END_MIN', 'END_QTR', 'ORIGIN_STAND','STAND_LAT', 'STAND_LONG', 'IS_HOSPITAL', 'IS_STADIUM', 'IS_UNIV', 'POLYLINE']]
print(train_cleaned.shape)
train_cleaned.head()
# Out:
# Index(['TRIP_ID', 'CALL_TYPE', 'ORIGIN_CALL', 'ORIGIN_STAND', 'TAXI_ID',
#        'TIMESTAMP', 'POLYLINE', 'tripTimeSec', 'END_TIMESTAMP', 'YR', 'MON',
#        'DAY', 'START_HR', 'START_MIN', 'WK_DAY', 'END_HR', 'END_MIN', 'ORIGIN',
#        'STAND_LAT', 'STAND_LONG', 'IS_HOSPITAL', 'IS_STADIUM', 'IS_UNIV',
#        'START_QTR', 'END_QTR'],
#       dtype='object')
# (122756, 23)
#                   TRIP_ID CALL_TYPE  ORIGIN_CALL   TAXI_ID   TIMESTAMP  \
# 2601  1372686333620000247         B          0.0  20000247  1372686333
# 3005  1372686607620000502         A       8402.0  20000502  1372686607
# 2699  1372687013620000473         C          0.0  20000473  1372687013
# 3087  1372687204620000406         B          0.0  20000406  1372687204
# 2689  1372687220620000617         C          0.0  20000617  1372687220
#
#       END_TIMESTAMP  tripTimeSec  MON  DAY  WK_DAY  ...  END_HR  END_MIN  \
# 2601     1372688493         2160    7    1       0  ...      14       21
# 3005     1372689157         2550    7    1       0  ...      14       32
# 2699     1372688183         1170    7    1       0  ...      14       16
# 3087     1372689484         2280    7    1       0  ...      14       38
# 2689     1372687880          660    7    1       0  ...      14       11
#
#       END_QTR  ORIGIN_STAND  STAND_LAT  STAND_LONG  IS_HOSPITAL  IS_STADIUM  \
# 2601        2          56.0  41.162879   -8.591645          0.0         0.0
# 3005        3           0.0   0.000000    0.000000          0.0         0.0
# 2699        2           0.0   0.000000    0.000000          0.0         0.0
# 3087        3           6.0  41.180804   -8.582783          0.0         0.0
# 2689        1           0.0   0.000000    0.000000          0.0         0.0
#
#       IS_UNIV                                           POLYLINE
# 2601      0.0  [[-8.591364,41.162751],[-8.590995,41.162499],[...
# 3005      0.0  [[-8.641629,41.161446],[-8.641629,41.161419],[...
# 2699      0.0  [[-8.570835,41.159979],[-8.569476,41.161176],[...
# 3087      0.0  [[-8.582616,41.180229],[-8.582355,41.180247],[...
# 2689      0.0  [[-8.689356,41.168088],[-8.688672,41.167359],[...
#
# [5 rows x 23 columns]

# %%
train_cleaned.to_csv('train_cleaned.csv', index=False)

# %%
train_cleaned.shape
# Out:
# (122756, 23)

# %%
mean = train_reduced['tripTimeSec'].mean()
std = train_reduced['tripTimeSec'].std()
print('mean: ' + str(mean))
print('std: ' + str(std))
print(train_reduced.shape)
sns.histplot(train_reduced['tripTimeSec'])
plt.axvline(x=mean, color='red')
plt.axvline(x=np.median(train_reduced['tripTimeSec']), color='yellow')
plt.title('histogram of trip length in seconds : postfiltering')
plt.xlabel("Trip Time (s)")
# Out:
# mean: 744.9569471146013
# std: 461.8033643640038
# (122756, 25)
# Text(0.5, 0, 'Trip Time (s)')
